# %%
# ==========================================
# 0. SIMPLE AUTHENTICATION & FILE FETCH
# ==========================================
import os
import sys
import urllib.request

# --- NEW: AUTO-FETCH FILES FOR COLAB ---
print("🔍 Fetching required dependencies...")
repo_url = "https://huggingface.co/spaces/Proteinrequired/enterprise-email-triage/resolve/main/"
files_needed = ["env.py", "dataset.json", "reward_system.py"]

for file in files_needed:
    if not os.path.exists(file):
        try:
            print(f"⬇️ Downloading {file}...")
            urllib.request.urlretrieve(repo_url + file, file)
        except Exception as e:
            print(f"⚠️ Could not download {file}. Error: {e}")
print("✅ All files ready!\n")
# ---------------------------------------

# !pip install huggingface_hub
from huggingface_hub import login

# Grab the secret if it exists (Works in HF Spaces)
hf_token = os.environ.get("HF_TOKEN")

if hf_token:
    # Silently log in so Unsloth can download the gated weights
    login(token=hf_token.strip())
    print("✅ Authenticated via Environment Secret. Ready to load Llama-3.2.")

elif "COLAB_RELEASE_TAG" in os.environ:
    # If in Colab, pop up a secure login widget for the judge
    print("☁️ Colab detected! Please log in to Hugging Face to download Llama-3.2:")
    from huggingface_hub import notebook_login
    notebook_login()

else:
    # Failsafe for local machines
    print("❌ ERROR: HF_TOKEN not found. Llama-3.2 download will fail.")
    sys.exit(1)

# ==========================================
# 1. THE STABLE ENVIRONMENT INSTALL
# ==========================================
# (Commented out for local runs, judges will run these if necessary)
import os
os.system('pip install "torch>=2.4.0,<2.11.0" torchvision torchaudio')
os.system('pip install unsloth unsloth_zoo')
os.system('pip install "trl==0.22.0" peft accelerate bitsandbytes openenv-core datasets matplotlib pandas')

import re
import json
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from datasets import Dataset
from unsloth import FastLanguageModel
from trl import SFTTrainer
from transformers import TrainingArguments

# Import the environment we just ensured exists
from env import EnterpriseEmailEnv

# ==========================================
# 2. LOAD THE FAST 3B MODEL
# ==========================================
print("Loading Unsloth 3B Model...")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
    max_seq_length = 512,
    dtype = None,
    load_in_4bit = True,
    token = hf_token, # Explicitly passing the token here
)

# Apply LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# ==========================================
# 3. GENERATE ROLLOUTS (BULLETPROOF PARSER)
# ==========================================
print("Initializing OpenEnv...")
env = EnterpriseEmailEnv()

def format_observation_to_prompt(obs):
    current_email = obs.get('current_email', {})
    email_id = current_email.get('email_id', 'UNKNOWN_ID')
    sender = current_email.get('sender', 'Unknown')
    subject = current_email.get('subject', 'No Subject')
    body = current_email.get('body', '')[:1000]

    prompt = f"""<|begin_of_text|><|start_header_id|>system<|end_header_id|>
You are a Corporate Email Triage Agent. You must respond ONLY with a JSON object.
### AVAILABLE TOOLS:
1. {{"tool": "route_to_human", "arguments": {{"email_id": "{email_id}", "department": "IT/Support/HR"}}}}
   *RULE: Use this for VIPs, Angry customers, Server Outages, or Sensitive HR issues.*
2. {{"tool": "auto_reply", "arguments": {{"email_id": "{email_id}", "message": "REPLY_TEXT"}}}}
   *RULE: Use this for routine tasks like password resets or feature requests.*
3. {{"tool": "ask_for_clarification", "arguments": {{"email_id": "{email_id}"}}}}
   *RULE: Use this only if the email is confusing or missing data.*
Always use the correct Email ID: {email_id}<|eot_id|><|start_header_id|>user<|end_header_id|>
Email ID: {email_id}
From: {sender}
Subject: {subject}
Body: {body}<|eot_id|><|start_header_id|>assistant<|end_header_id|>"""
    return prompt

def collect_rollouts(env, model, tokenizer, num_episodes=30):
    rollout_data = []
    FastLanguageModel.for_inference(model)

    for episode in tqdm(range(num_episodes), desc="Collecting rollouts"):
        obs = env.reset()
        episode_data = []

        while not env.current_step >= env.max_steps and len(env.processed_emails) < len(env.emails):
            prompt = format_observation_to_prompt(obs)
            inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, max_length=2048).to(model.device)

            with torch.no_grad():
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=300,
                    temperature=0.1,
                    do_sample=True,
                    pad_token_id=tokenizer.eos_token_id,
                )

            generated_text = tokenizer.decode(outputs[0][inputs.input_ids.shape[-1]:], skip_special_tokens=True)

            start_idx = generated_text.find('{')
            end_idx = generated_text.rfind('}') + 1

            if start_idx != -1 and end_idx != 0:
                clean_json = generated_text[start_idx:end_idx]
                try:
                    action = json.loads(clean_json)
                    if "tool" not in action or "arguments" not in action:
                        action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}
                except:
                    action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}
            else:
                action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}

            next_obs, reward, done, info = env.step(action)

            episode_data.append({
                "prompt": prompt,
                "action": action,
                "reward": reward,
                "observation": next_obs
            })

            print(f"Step {env.current_step}: {action['tool']} -> Reward: {reward:+.2f} | Total: {env.total_reward:+.2f}")
            obs = next_obs
            if done: break

        rollout_data.extend(episode_data)

    FastLanguageModel.for_training(model)
    return rollout_data

print("Collecting rollouts (playing the game)...")
rollout_data = collect_rollouts(env, model, tokenizer, num_episodes=30)
print(f"Collected {len(rollout_data)} transitions")

# ==========================================
# 4. PREPARE BEHAVIORAL CLONING DATASET
# ==========================================
print("Filtering for successful behaviors...")
winning_rollouts = [item for item in rollout_data if item["reward"] > 0]
print(f"Found {len(winning_rollouts)} highly successful actions to train on!")

sft_dataset_dict = {
    "text": [item["prompt"] + json.dumps(item["action"]) + tokenizer.eos_token for item in winning_rollouts]
}
sft_dataset = Dataset.from_dict(sft_dataset_dict)

# ==========================================
# 5. INITIALIZE SFT TRAINER
# ==========================================
print("Configuring SFT Trainer...")
sft_config = TrainingArguments(
    output_dir="email-triage-lora-final",
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    logging_steps=1,
    max_steps=60,
    optim="adamw_8bit",
    fp16=not torch.cuda.is_bf16_supported(),
    bf16=torch.cuda.is_bf16_supported(),
)

sft_trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=sft_dataset,
    dataset_text_field="text",
    max_seq_length=512,
    args=sft_config,
)

# ==========================================
# 6. EXECUTE TRAINING & SAVE DELIVERABLES
# ==========================================
print("Starting Behavioral Cloning Training...")
sft_trainer.train()

print("Training completed! Saving LoRA adapters...")
model.save_pretrained("email-triage-lora-final")
tokenizer.save_pretrained("email-triage-lora-final")
print("SUCCESS: Model weights saved locally!")

# ==========================================
# 7. GENERATE HACKATHON EVIDENCE (PLOTS)
# ==========================================
print("Generating validation plots...")

# Plot 1: Training Loss
try:
    history = sft_trainer.state.log_history
    steps = [x['step'] for x in history if 'loss' in x]
    loss = [x['loss'] for x in history if 'loss' in x]

    if loss:
        plt.figure(figsize=(10, 5))
        plt.plot(steps, loss, color='#1f77b4', linewidth=2, label='Training Loss')
        plt.title('Agent Training Loss: Enterprise Email Triage')
        plt.xlabel('Step')
        plt.ylabel('Loss')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend()
        plt.savefig('training_loss.png')
        print("✅ Saved training_loss.png")
except Exception as e:
    print(f"⚠️ Could not generate loss curve: {e}")

# Plot 2: Reward Distribution
try:
    rewards = [item['reward'] for item in rollout_data]
    if rewards:
        plt.figure(figsize=(10, 5))
        plt.hist(rewards, bins=10, color='green', alpha=0.7, edgecolor='black')
        plt.title('Expert Rollout Reward Distribution')
        plt.xlabel('Reward Value')
        plt.ylabel('Frequency')
        plt.axvline(0, color='red', linestyle='--')
        plt.savefig('reward_curve.png')
        print("✅ Saved reward_curve.png")
except Exception as e:
    print(f"⚠️ Could not generate reward curve: {e}")

print("🎉 ALL TASKS COMPLETE. Script is ready for judging!")
# Out:
# 🔍 Fetching required dependencies...
# ✅ All files ready!
#
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# ☁️ Colab detected! Please log in to Hugging Face to download Llama-3.2:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Loading Unsloth 3B Model...
# ==((====))==  Unsloth 2026.4.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth: Will load unsloth/Llama-3.2-3B-Instruct-bnb-4bit as a legacy tokenizer.
# Unsloth 2026.4.8 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# Initializing OpenEnv...
# ✅ Successfully loaded 100 emails from dataset.json
# Collecting rollouts (playing the game)...
# Collecting rollouts:   0%|          | 0/30 [00:00<?, ?it/s]
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: +0.83 | Total: +0.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: +0.83 | Total: +1.66
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: ask_for_clarification -> Reward: -0.37 | Total: +1.29
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: -0.97 | Total: +0.32
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: -0.67 | Total: -0.35
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: -0.97 | Total: -1.32
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: -0.49
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +0.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: -0.03
# Collecting rollouts:   3%|▎         | 1/30 [00:27<13:18, 27.53s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: -0.97 | Total: -1.00
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: -0.67 | Total: -0.67
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +1.14 | Total: +0.47
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: +0.83 | Total: +1.30
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: +0.93
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: +0.93 | Total: +1.86
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: -0.67 | Total: +1.19
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +0.94 | Total: +2.13
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: -0.98 | Total: +1.15
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: auto_reply -> Reward: +0.93 | Total: +2.08
# Collecting rollouts:   7%|▋         | 2/30 [01:00<14:24, 30.87s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +2.91
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: +0.93 | Total: +0.93
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: ask_for_clarification -> Reward: -0.37 | Total: +0.56
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: +0.83 | Total: +1.39
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: +0.63 | Total: +2.02
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: -0.67 | Total: +1.35
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +2.18
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: -0.97 | Total: +1.21
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +2.04
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: auto_reply -> Reward: -0.67 | Total: +1.37
# Collecting rollouts:  10%|█         | 3/30 [01:27<13:04, 29.07s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +2.20
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: +0.83 | Total: +0.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: ask_for_clarification -> Reward: -0.37 | Total: +0.46
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: +0.94 | Total: +1.40
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: +0.83 | Total: +2.23
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: +1.86
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +2.69
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: -0.97 | Total: +1.72
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: ask_for_clarification -> Reward: -0.37 | Total: +1.35
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: +0.98
# Collecting rollouts:  13%|█▎        | 4/30 [01:47<10:57, 25.27s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: -0.98 | Total: +0.00
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: +0.83 | Total: +0.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: ask_for_clarification -> Reward: -0.37 | Total: +0.46
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: +0.83 | Total: +1.29
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: +0.83 | Total: +2.12
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: +1.75
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: +0.93 | Total: +2.68
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +3.51
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +4.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: +0.83 | Total: +5.17
# Collecting rollouts:  17%|█▋        | 5/30 [02:10<10:12, 24.49s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: auto_reply -> Reward: -0.67 | Total: +4.50
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: +0.83 | Total: +0.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: +0.63 | Total: +1.46
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: ask_for_clarification -> Reward: -0.37 | Total: +1.09
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: +0.72
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: +0.35
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: +0.94 | Total: +1.29
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: -0.67 | Total: +0.62
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: -0.98 | Total: -0.36
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: -0.97 | Total: -1.33
# Collecting rollouts:  20%|██        | 6/30 [02:31<09:17, 23.23s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: -0.97 | Total: -2.30
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: -0.67 | Total: -0.67
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +0.94 | Total: +0.27
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: +1.14 | Total: +1.41
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: -0.97 | Total: +0.44
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: +0.93 | Total: +1.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: ask_for_clarification -> Reward: -0.37 | Total: +1.00
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +1.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: ask_for_clarification -> Reward: -0.37 | Total: +1.46
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: +0.83 | Total: +2.29
# Collecting rollouts:  23%|██▎       | 7/30 [02:57<09:15, 24.17s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.63 | Total: +2.92
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: -0.67 | Total: -1.04
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: -0.98 | Total: -2.02
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: +0.83 | Total: -1.19
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: -1.56
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: -0.73
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +0.10
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: +1.14 | Total: +1.24
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: +0.87
# Collecting rollouts:  27%|██▋       | 8/30 [03:17<08:28, 23.11s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: ask_for_clarification -> Reward: -0.37 | Total: +0.50
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: +1.14 | Total: +1.14
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: +0.83 | Total: +1.97
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: -0.67 | Total: +1.30
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: -0.98 | Total: +0.32
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: -0.05
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: -0.97 | Total: -1.02
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: -0.19
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +0.64
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: +0.27
# Collecting rollouts:  30%|███       | 9/30 [03:40<08:01, 22.93s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: ask_for_clarification -> Reward: -0.37 | Total: -0.10
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: -0.97 | Total: -0.97
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: -0.62 | Total: -1.59
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: +0.94 | Total: -0.65
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: -1.02
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: -0.67 | Total: -1.69
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: ask_for_clarification -> Reward: -0.37 | Total: -2.06
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +0.94 | Total: -1.12
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: +1.14 | Total: +0.02
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: -0.97 | Total: -0.95
# Collecting rollouts:  33%|███▎      | 10/30 [04:06<07:57, 23.90s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.63 | Total: -0.32
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: route_to_human -> Reward: +0.83 | Total: +0.83
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +0.93 | Total: +1.76
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: +0.83 | Total: +2.59
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: auto_reply -> Reward: -0.67 | Total: +1.92
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: +2.75
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +3.58
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +0.93 | Total: +4.51
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: -0.97 | Total: +3.54
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: auto_reply -> Reward: +0.93 | Total: +4.47
# Collecting rollouts:  37%|███▋      | 11/30 [04:38<08:21, 26.40s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +5.30
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: +0.83 | Total: +0.46
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: +0.94 | Total: +1.40
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: route_to_human -> Reward: -0.97 | Total: +0.43
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: ask_for_clarification -> Reward: -0.37 | Total: +0.06
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +0.89
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +1.72
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: ask_for_clarification -> Reward: -0.37 | Total: +1.35
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: +0.83 | Total: +2.18
# Collecting rollouts:  40%|████      | 12/30 [04:59<07:22, 24.58s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +3.01
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +0.94 | Total: +0.57
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: ask_for_clarification -> Reward: -0.37 | Total: +0.20
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: -0.17
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: auto_reply -> Reward: +0.94 | Total: +0.77
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: +1.14 | Total: +1.91
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +1.14 | Total: +3.05
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +3.88
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# Step 6: ask_for_clarification -> Reward: -0.37 | Total: +0.09
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: -0.67 | Total: -0.58
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: -0.67 | Total: -1.25
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: -1.62
# Collecting rollouts:  90%|█████████ | 27/30 [11:24<01:12, 24.23s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: -0.79
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +0.93 | Total: +0.56
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: ask_for_clarification -> Reward: -0.37 | Total: +0.19
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: auto_reply -> Reward: +1.14 | Total: +1.33
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: +2.16
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: -0.98 | Total: +1.18
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +2.01
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: -0.67 | Total: +1.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: -0.97 | Total: +0.37
# Collecting rollouts:  93%|█████████▎| 28/30 [11:49<00:48, 24.44s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +1.20
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: -0.97 | Total: -1.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: -0.67 | Total: -2.01
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: auto_reply -> Reward: +0.93 | Total: -1.08
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: -0.25
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +0.58
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: -0.67 | Total: -0.09
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +0.74
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: auto_reply -> Reward: +0.93 | Total: +1.67
# Collecting rollouts:  97%|█████████▋| 29/30 [12:20<00:26, 26.25s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: ask_for_clarification -> Reward: -0.37 | Total: +1.30
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: -0.67 | Total: -0.67
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: -0.98 | Total: -1.65
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: -0.97 | Total: -2.62
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: -2.99
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: -2.16
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: +0.94 | Total: -1.22
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +1.14 | Total: -0.08
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: +0.93 | Total: +0.85
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: +0.48
# Collecting rollouts: 100%|██████████| 30/30 [12:51<00:00, 25.70s/it]
# Step 10: auto_reply -> Reward: -0.67 | Total: -0.19
# Collected 300 transitions
# Filtering for successful behaviors...
# Found 157 highly successful actions to train on!
# Configuring SFT Trainer...
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/157 [00:00<?, ? examples/s]
# Starting Behavioral Cloning Training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 157 | Num Epochs = 6 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 4 x 1) = 16
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 05:37, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.152883</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.022747</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.767257</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.552131</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.428172</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.220372</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.998826</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.852252</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.714095</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.550235</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.452012</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.370951</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.339939</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.312247</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.291677</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.283311</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.266445</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.257108</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.246741</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.237073</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.231704</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.226140</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.223047</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.209619</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.206410</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.188748</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.193096</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.196588</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.202704</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.176750</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.177845</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.178486</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.169722</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.168342</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.168780</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.168199</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.158695</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.163469</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.156987</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.164859</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.150555</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.156389</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.136087</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.154172</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.151162</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.144176</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.138656</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.140523</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.140241</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.142222</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.136642</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.128443</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.136383</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.136021</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.141095</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.131959</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.134330</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.140001</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.134156</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.133044</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in email-triage-lora-final/checkpoint-60/tokenizer_config.json.
# Training completed! Saving LoRA adapters...
# Unsloth: Restored added_tokens_decoder metadata in email-triage-lora-final/tokenizer_config.json.
# SUCCESS: Model weights saved locally!
# Generating validation plots...
# ✅ Saved training_loss.png
# ✅ Saved reward_curve.png
# 🎉 ALL TASKS COMPLETE. Script is ready for judging!
