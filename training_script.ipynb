# %%
# ==========================================
# 0. SIMPLE AUTHENTICATION (FOR GATED MODEL)
# ==========================================
import os
import sys
# !pip install huggingface_hub
from huggingface_hub import login

# Grab the secret you set in the HF Space UI
hf_token = os.environ.get("HF_TOKEN")

if not hf_token:
    print("❌ ERROR: HF_TOKEN not found in Secrets. Llama-3.2 download will fail.")
    sys.exit(1)

# Silently log in so Unsloth can download the gated weights
login(token=hf_token.strip())
print("✅ Authenticated. Ready to load Llama-3.2.")

# ==========================================
# 1. THE STABLE ENVIRONMENT INSTALL
# ==========================================
# (Commented out for local runs, judges will run these if necessary)
import os
os.system('pip install "torch>=2.4.0,<2.11.0" torchvision torchaudio')
os.system('pip install unsloth unsloth_zoo')
os.system('pip install "trl==0.22.0" peft accelerate bitsandbytes openenv-core datasets matplotlib pandas')

import re
import json
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from datasets import Dataset
from unsloth import FastLanguageModel
from trl import SFTTrainer
from transformers import TrainingArguments

# Import the environment we just ensured exists
from env import EnterpriseEmailEnv

# ==========================================
# 2. LOAD THE FAST 3B MODEL
# ==========================================
print("Loading Unsloth 3B Model...")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit", 
    max_seq_length = 512,
    dtype = None,
    load_in_4bit = True,
    token = hf_token, # Explicitly passing the token here
)

# Apply LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# ==========================================
# 3. GENERATE ROLLOUTS (BULLETPROOF PARSER)
# ==========================================
print("Initializing OpenEnv...")
env = EnterpriseEmailEnv()

def format_observation_to_prompt(obs):
    current_email = obs.get('current_email', {})
    email_id = current_email.get('email_id', 'UNKNOWN_ID')
    sender = current_email.get('sender', 'Unknown')
    subject = current_email.get('subject', 'No Subject')
    body = current_email.get('body', '')[:1000] 
    
    prompt = f"""<|begin_of_text|><|start_header_id|>system<|end_header_id|>
You are a Corporate Email Triage Agent. You must respond ONLY with a JSON object.
### AVAILABLE TOOLS:
1. {{"tool": "route_to_human", "arguments": {{"email_id": "{email_id}", "department": "IT/Support/HR"}}}}
   *RULE: Use this for VIPs, Angry customers, Server Outages, or Sensitive HR issues.*
2. {{"tool": "auto_reply", "arguments": {{"email_id": "{email_id}", "message": "REPLY_TEXT"}}}}
   *RULE: Use this for routine tasks like password resets or feature requests.*
3. {{"tool": "ask_for_clarification", "arguments": {{"email_id": "{email_id}"}}}}
   *RULE: Use this only if the email is confusing or missing data.*
Always use the correct Email ID: {email_id}<|eot_id|><|start_header_id|>user<|end_header_id|>
Email ID: {email_id}
From: {sender}
Subject: {subject}
Body: {body}<|eot_id|><|start_header_id|>assistant<|end_header_id|>"""
    return prompt

def collect_rollouts(env, model, tokenizer, num_episodes=30):
    rollout_data = []
    FastLanguageModel.for_inference(model)

    for episode in tqdm(range(num_episodes), desc="Collecting rollouts"):
        obs = env.reset()
        episode_data = []

        while not env.current_step >= env.max_steps and len(env.processed_emails) < len(env.emails):
            prompt = format_observation_to_prompt(obs)
            inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, max_length=2048).to(model.device)

            with torch.no_grad():
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=300, 
                    temperature=0.1,
                    do_sample=True,
                    pad_token_id=tokenizer.eos_token_id,
                )

            generated_text = tokenizer.decode(outputs[0][inputs.input_ids.shape[-1]:], skip_special_tokens=True)

            start_idx = generated_text.find('{')
            end_idx = generated_text.rfind('}') + 1
            
            if start_idx != -1 and end_idx != 0:
                clean_json = generated_text[start_idx:end_idx]
                try:
                    action = json.loads(clean_json)
                    if "tool" not in action or "arguments" not in action:
                        action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}
                except:
                    action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}
            else:
                action = {"tool": "ask_for_clarification", "arguments": {"email_id": obs['current_email']['email_id']}}

            next_obs, reward, done, info = env.step(action)

            episode_data.append({
                "prompt": prompt,
                "action": action,
                "reward": reward,
                "observation": next_obs
            })

            print(f"Step {env.current_step}: {action['tool']} -> Reward: {reward:+.2f} | Total: {env.total_reward:+.2f}")
            obs = next_obs
            if done: break

        rollout_data.extend(episode_data)
    
    FastLanguageModel.for_training(model)
    return rollout_data

print("Collecting rollouts (playing the game)...")
rollout_data = collect_rollouts(env, model, tokenizer, num_episodes=30)
print(f"Collected {len(rollout_data)} transitions")

# ==========================================
# 4. PREPARE BEHAVIORAL CLONING DATASET
# ==========================================
print("Filtering for successful behaviors...")
winning_rollouts = [item for item in rollout_data if item["reward"] > 0]
print(f"Found {len(winning_rollouts)} highly successful actions to train on!")

sft_dataset_dict = {
    "text": [item["prompt"] + json.dumps(item["action"]) + tokenizer.eos_token for item in winning_rollouts]
}
sft_dataset = Dataset.from_dict(sft_dataset_dict)

# ==========================================
# 5. INITIALIZE SFT TRAINER
# ==========================================
print("Configuring SFT Trainer...")
sft_config = TrainingArguments(
    output_dir="email-triage-lora-final",
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    logging_steps=1,
    max_steps=60, 
    optim="adamw_8bit",
    fp16=not torch.cuda.is_bf16_supported(),
    bf16=torch.cuda.is_bf16_supported(),
)

sft_trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=sft_dataset,
    dataset_text_field="text",
    max_seq_length=512,
    args=sft_config,
)

# ==========================================
# 6. EXECUTE TRAINING & SAVE DELIVERABLES
# ==========================================
print("Starting Behavioral Cloning Training...")
sft_trainer.train()

print("Training completed! Saving LoRA adapters...")
model.save_pretrained("email-triage-lora-final")
tokenizer.save_pretrained("email-triage-lora-final")
print("SUCCESS: Model weights saved locally!")

# ==========================================
# 7. GENERATE HACKATHON EVIDENCE (PLOTS)
# ==========================================
print("Generating validation plots...")

# Plot 1: Training Loss
try:
    history = sft_trainer.state.log_history
    steps = [x['step'] for x in history if 'loss' in x]
    loss = [x['loss'] for x in history if 'loss' in x]

    if loss:
        plt.figure(figsize=(10, 5))
        plt.plot(steps, loss, color='#1f77b4', linewidth=2, label='Training Loss')
        plt.title('Agent Training Loss: Enterprise Email Triage')
        plt.xlabel('Step')
        plt.ylabel('Loss')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend()
        plt.savefig('training_loss.png')
        print("✅ Saved training_loss.png")
except Exception as e:
    print(f"⚠️ Could not generate loss curve: {e}")

# Plot 2: Reward Distribution
try:
    rewards = [item['reward'] for item in rollout_data]
    if rewards:
        plt.figure(figsize=(10, 5))
        plt.hist(rewards, bins=10, color='green', alpha=0.7, edgecolor='black')
        plt.title('Expert Rollout Reward Distribution')
        plt.xlabel('Reward Value')
        plt.ylabel('Frequency')
        plt.axvline(0, color='red', linestyle='--')
        plt.savefig('reward_curve.png')
        print("✅ Saved reward_curve.png")
except Exception as e:
    print(f"⚠️ Could not generate reward curve: {e}")

print("🎉 ALL TASKS COMPLETE. Script is ready for judging!")
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.8/646.8 kB 46.1 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 86.2 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.4.3
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 139.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub) (6.0.3)
# Collecting typer
#   Downloading typer-0.24.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub) (0.28.1)
# Collecting filelock>=3.10.0
#   Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub) (4.64.1)
# Requirement already satisfied: certifi in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.4.22)
# Requirement already satisfied: idna in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.4)
# Requirement already satisfied: httpcore==1.* in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: anyio in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: h11>=0.16 in /home/user/miniconda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting rich>=12.3.0
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 100.0 MB/s eta 0:00:00
# Collecting click>=8.2.1
#   Downloading click-8.3.3-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 62.0 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/user/miniconda/lib/python3.10/site-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/user/miniconda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: shellingham, mdurl, hf-xet, fsspec, filelock, click, annotated-doc, markdown-it-py, rich, typer, huggingface_hub
# Successfully installed annotated-doc-0.0.4 click-8.3.3 filelock-3.29.0 fsspec-2026.3.0 hf-xet-1.4.3 huggingface_hub-1.12.0 markdown-it-py-4.0.0 mdurl-0.1.2 rich-15.0.0 shellingham-1.5.4 typer-0.24.2
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ Authenticated. Ready to load Llama-3.2.
# Collecting torch<2.11.0,>=2.4.0
#   Downloading torch-2.10.0-3-cp310-cp310-manylinux_2_28_x86_64.whl (915.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.5/915.5 MB 1.6 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 136.4 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 148.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.8 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 50.2 MB/s eta 0:00:00
# Collecting cuda-bindings==12.9.4
#   Downloading cuda_bindings-12.9.4-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 49.5 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 70.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0) (4.15.0)
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 139.3 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0) (3.1.6)
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 9.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 54.8 MB/s eta 0:00:00
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 9.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-nvshmem-cu12==3.4.5
#   Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 MB 8.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.2 MB/s eta 0:00:00
# Collecting triton==3.6.0
#   Downloading triton-3.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.1/188.1 MB 22.7 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 54.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=0.8.5 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0) (2026.3.0)
# Collecting nvidia-nccl-cu12==2.27.5
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0) (3.29.0)
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 59.6 MB/s eta 0:00:00
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 18.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 31.2 MB/s eta 0:00:00
# Collecting cuda-pathfinder~=1.1
#   Downloading cuda_pathfinder-1.5.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 31.6 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 141.2 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 143.5 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp310-cp310-manylinux_2_28_x86_64.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 175.8 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 100.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/miniconda/lib/python3.10/site-packages (from jinja2->torch<2.11.0,>=2.4.0) (3.0.3)
# Installing collected packages: torchaudio, nvidia-cusparselt-cu12, mpmath, triton, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, cuda-pathfinder, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, cuda-bindings, nvidia-cusolver-cu12, torch, torchvision
# Successfully installed cuda-bindings-12.9.4 cuda-pathfinder-1.5.3 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.4.5 nvidia-nvtx-cu12-12.8.90 pillow-12.2.0 sympy-1.14.0 torch-2.10.0 torchaudio-2.11.0 torchvision-0.25.0 triton-3.6.0
# Collecting unsloth
#   Downloading unsloth-2026.4.8-py3-none-any.whl (67.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 49.7 MB/s eta 0:00:00
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2026.4.9-py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 117.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (0.25.0)
# Collecting protobuf
#   Downloading protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: triton>=3.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (3.6.0)
# Requirement already satisfied: pyyaml in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (6.0.3)
# Collecting accelerate>=0.34.1
#   Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 44.9 MB/s eta 0:00:00
# Collecting sentencepiece>=0.2.0
#   Downloading sentencepiece-0.2.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (2.2.6)
# Requirement already satisfied: torch<2.11.0,>=2.4.0 in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (2.10.0)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2
#   Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (1.6.0)
# Requirement already satisfied: packaging in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (26.2)
# Collecting wheel>=0.42.0
#   Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Collecting bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 55.8 MB/s eta 0:00:00
# Collecting pydantic
#   Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.0/472.0 kB 126.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub>=0.34.0 in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (1.12.0)
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1
#   Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 70.9 MB/s eta 0:00:00
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3
#   Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 142.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (7.2.2)
# Requirement already satisfied: tqdm in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (4.64.1)
# Collecting hf_transfer
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 135.2 MB/s eta 0:00:00
# Collecting tyro
#   Downloading tyro-1.0.13-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 75.8 MB/s eta 0:00:00
# Collecting peft!=0.11.0,>=0.18.0
#   Downloading peft-0.19.1-py3-none-any.whl (680 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: typer in /home/user/miniconda/lib/python3.10/site-packages (from unsloth) (0.24.2)
# Collecting diffusers
#   Downloading diffusers-0.37.1-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 135.2 MB/s eta 0:00:00
# Collecting xformers>=0.0.27.post2
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 167.7 MB/s eta 0:00:00
# Collecting msgspec
#   Downloading msgspec-0.21.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 kB 91.8 MB/s eta 0:00:00
# Collecting torchao>=0.13.0
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 171.5 MB/s eta 0:00:00
# Collecting cut_cross_entropy
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: pillow in /home/user/miniconda/lib/python3.10/site-packages (from unsloth_zoo) (12.2.0)
# Requirement already satisfied: filelock in /home/user/miniconda/lib/python3.10/site-packages (from unsloth_zoo) (3.29.0)
# Collecting regex
#   Downloading regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (793 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 147.3 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions in /home/user/miniconda/lib/python3.10/site-packages (from unsloth_zoo) (4.15.0)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.2/507.2 kB 135.6 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 132.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32.2 in /home/user/miniconda/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.28.1)
# Collecting xxhash
#   Downloading xxhash-3.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.3/193.3 kB 88.6 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 46.5 MB/s eta 0:00:00
# Collecting fsspec[http]<=2025.9.0,>=2023.1.0
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 90.4 MB/s eta 0:00:00
# Collecting pyarrow>=21.0.0
#   Downloading pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (48.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 MB 62.5 MB/s eta 0:00:00
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 72.0 MB/s eta 0:00:00
# Collecting dill<0.4.1,>=0.3.0
#   Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth) (1.4.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.4.5)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.9.4)
# Requirement already satisfied: jinja2 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: networkx>=2.5.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (2.27.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: sympy>=1.13.3 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/user/miniconda/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.4.0->unsloth) (1.5.3)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 145.5 MB/s eta 0:00:00
# Collecting importlib-metadata
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Collecting pydantic-core==2.46.3
#   Downloading pydantic_core-2.46.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 127.2 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/user/miniconda/lib/python3.10/site-packages (from typer->unsloth) (0.0.4)
# Requirement already satisfied: click>=8.2.1 in /home/user/miniconda/lib/python3.10/site-packages (from typer->unsloth) (8.3.3)
# Requirement already satisfied: rich>=12.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from typer->unsloth) (15.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from typer->unsloth) (1.5.4)
# Collecting docstring-parser>=0.15
#   Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Collecting typeguard>=4.0.0
#   Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.13.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 127.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.4)
# Requirement already satisfied: certifi in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.4.22)
# Requirement already satisfied: anyio in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /home/user/miniconda/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/user/miniconda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.16.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/user/miniconda/lib/python3.10/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.26.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/user/miniconda/lib/python3.10/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/user/miniconda/lib/python3.10/site-packages (from rich>=12.3.0->typer->unsloth) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/user/miniconda/lib/python3.10/site-packages (from rich>=12.3.0->typer->unsloth) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/user/miniconda/lib/python3.10/site-packages (from sympy>=1.13.3->torch<2.11.0,>=2.4.0->unsloth) (1.3.0)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/miniconda/lib/python3.10/site-packages (from jinja2->torch<2.11.0,>=2.4.0->unsloth) (3.0.3)
# Collecting pytz>=2020.1
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 116.3 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniconda/lib/python3.10/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/miniconda/lib/python3.10/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 96.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (26.1.0)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.23.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 54.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.5/219.5 kB 96.0 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.9/196.9 kB 90.4 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: mdurl~=0.1 in /home/user/miniconda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/user/miniconda/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.3.1)
# Installing collected packages: torchao, pytz, zipp, xxhash, wheel, typing-inspection, typeguard, tqdm, sentencepiece, safetensors, regex, pydantic-core, pyarrow, protobuf, propcache, multidict, msgspec, hf_transfer, fsspec, frozenlist, docstring-parser, dill, async-timeout, annotated-types, aiohappyeyeballs, yarl, tyro, pydantic, pandas, multiprocess, importlib-metadata, aiosignal, aiohttp, xformers, cut_cross_entropy, bitsandbytes, tokenizers, diffusers, datasets, accelerate, transformers, trl, peft, unsloth_zoo, unsloth
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2026.3.0
#     Uninstalling fsspec-2026.3.0:
#       Successfully uninstalled fsspec-2026.3.0
# Successfully installed accelerate-1.13.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-types-0.7.0 async-timeout-5.0.1 bitsandbytes-0.49.2 cut_cross_entropy-25.1.1 datasets-4.3.0 diffusers-0.37.1 dill-0.4.0 docstring-parser-0.18.0 frozenlist-1.8.0 fsspec-2025.9.0 hf_transfer-0.1.9 importlib-metadata-9.0.0 msgspec-0.21.1 multidict-6.7.1 multiprocess-0.70.16 pandas-2.3.3 peft-0.19.1 propcache-0.4.1 protobuf-7.34.1 pyarrow-24.0.0 pydantic-2.13.3 pydantic-core-2.46.3 pytz-2026.1.post1 regex-2026.4.4 safetensors-0.7.0 sentencepiece-0.2.1 tokenizers-0.22.2 torchao-0.17.0 tqdm-4.67.3 transformers-5.5.0 trl-0.24.0 typeguard-4.5.1 typing-inspection-0.4.2 tyro-1.0.13 unsloth-2026.4.8 unsloth_zoo-2026.4.9 wheel-0.47.0 xformers-0.0.35 xxhash-3.7.0 yarl-1.23.0 zipp-3.23.1
# Collecting trl==0.22.0
#   Downloading trl-0.22.0-py3-none-any.whl (544 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: peft in /home/user/miniconda/lib/python3.10/site-packages (0.19.1)
# Requirement already satisfied: accelerate in /home/user/miniconda/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: bitsandbytes in /home/user/miniconda/lib/python3.10/site-packages (0.49.2)
# Collecting openenv-core
#   Downloading openenv_core-0.2.3-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /home/user/miniconda/lib/python3.10/site-packages (4.3.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 108.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /home/user/miniconda/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: transformers>=4.55.0 in /home/user/miniconda/lib/python3.10/site-packages (from trl==0.22.0) (5.5.0)
# Requirement already satisfied: numpy>=1.17 in /home/user/miniconda/lib/python3.10/site-packages (from peft) (2.2.6)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/user/miniconda/lib/python3.10/site-packages (from peft) (1.12.0)
# Requirement already satisfied: psutil in /home/user/miniconda/lib/python3.10/site-packages (from peft) (7.2.2)
# Requirement already satisfied: tqdm in /home/user/miniconda/lib/python3.10/site-packages (from peft) (4.67.3)
# Requirement already satisfied: pyyaml in /home/user/miniconda/lib/python3.10/site-packages (from peft) (6.0.3)
# Requirement already satisfied: safetensors in /home/user/miniconda/lib/python3.10/site-packages (from peft) (0.7.0)
# Requirement already satisfied: torch>=1.13.0 in /home/user/miniconda/lib/python3.10/site-packages (from peft) (2.10.0)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda/lib/python3.10/site-packages (from peft) (26.2)
# Collecting openai>=2.7.2
#   Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 141.3 MB/s eta 0:00:00
# Collecting websockets>=15.0.1
#   Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 86.1 MB/s eta 0:00:00
# Collecting tomli-w>=1.2.0
#   Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Collecting fastmcp>=3.0.0
#   Downloading fastmcp-3.2.4-py3-none-any.whl (728 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.6/728.6 kB 143.5 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=2.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (2.4.1)
# Requirement already satisfied: rich>=13.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (15.0.0)
# Collecting uvicorn>=0.24.0
#   Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 45.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (2.33.1)
# Collecting gradio>=4.0.0
#   Downloading gradio-6.13.0-py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 112.1 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (0.24.2)
# Requirement already satisfied: pydantic>=2.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (2.13.3)
# Collecting fastapi>=0.104.0
#   Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 61.6 MB/s eta 0:00:00
# Requirement already satisfied: httpx>=0.28.1 in /home/user/miniconda/lib/python3.10/site-packages (from openenv-core) (0.28.1)
# Requirement already satisfied: multiprocess<0.70.17 in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: fsspec[http]<=2025.9.0,>=2023.1.0 in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (2025.9.0)
# Requirement already satisfied: filelock in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: xxhash in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from datasets) (24.0.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 108.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8 in /home/user/miniconda/lib/python3.10/site-packages (from matplotlib) (12.2.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 157.1 MB/s eta 0:00:00
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 60.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 161.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/miniconda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/miniconda/lib/python3.10/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniconda/lib/python3.10/site-packages (from pandas) (2026.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/user/miniconda/lib/python3.10/site-packages (from fastapi>=0.104.0->openenv-core) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/user/miniconda/lib/python3.10/site-packages (from fastapi>=0.104.0->openenv-core) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/user/miniconda/lib/python3.10/site-packages (from fastapi>=0.104.0->openenv-core) (4.15.0)
# Collecting starlette>=0.46.0
#   Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 42.1 MB/s eta 0:00:00
# Collecting openapi-pydantic>=0.5.1
#   Downloading openapi_pydantic-0.5.1-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 56.1 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.2.2 in /home/user/miniconda/lib/python3.10/site-packages (from fastmcp>=3.0.0->openenv-core) (1.3.1)
# Collecting griffelib>=2.0.0
#   Downloading griffelib-2.0.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 77.8 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=4.0.0 in /home/user/miniconda/lib/python3.10/site-packages (from fastmcp>=3.0.0->openenv-core) (4.9.6)
# Collecting watchfiles>=1.0.0
#   Downloading watchfiles-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.6/455.6 kB 127.2 MB/s eta 0:00:00
# Collecting uncalled-for>=0.2.0
#   Downloading uncalled_for-0.3.1-py3-none-any.whl (11 kB)
# Collecting py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4
#   Downloading py_key_value_aio-0.4.4-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.3/152.3 kB 75.6 MB/s eta 0:00:00
# Collecting python-dotenv>=1.1.0
#   Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Collecting opentelemetry-api>=1.20.0
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 42.9 MB/s eta 0:00:00
# Collecting authlib>=1.6.5
#   Downloading authlib-1.7.0-py2.py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 kB 103.4 MB/s eta 0:00:00
# Collecting mcp<2.0,>=1.24.0
#   Downloading mcp-1.27.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 95.5 MB/s eta 0:00:00
# Collecting jsonschema-path>=0.3.4
#   Downloading jsonschema_path-0.4.5-py3-none-any.whl (19 kB)
# Collecting cyclopts>=4.0.0
#   Downloading cyclopts-4.11.0-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 98.4 MB/s eta 0:00:00
# Collecting jsonref>=1.1.0
#   Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Collecting pyperclip>=1.9.0
#   Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/user/miniconda/lib/python3.10/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.5)
# Collecting hf-gradio<1.0,>=0.4.1
#   Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Collecting gradio-client==2.5.0
#   Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<4.0 in /home/user/miniconda/lib/python3.10/site-packages (from gradio>=4.0.0->openenv-core) (3.1.6)
# Collecting brotli>=1.1.0
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 155.1 MB/s eta 0:00:00
# Collecting groovy~=0.1
#   Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Collecting safehttpx<0.2.0,>=0.1.7
#   Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Collecting semantic-version~=2.0
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/user/miniconda/lib/python3.10/site-packages (from gradio>=4.0.0->openenv-core) (3.0.3)
# Collecting pydub<1.0
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting orjson~=3.0
#   Downloading orjson-3.11.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 55.2 MB/s eta 0:00:00
# Collecting python-multipart<1.0,>=0.0.18
#   Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/user/miniconda/lib/python3.10/site-packages (from gradio>=4.0.0->openenv-core) (4.13.0)
# Collecting tomlkit<0.15.0,>=0.12.0
#   Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi in /home/user/miniconda/lib/python3.10/site-packages (from httpx>=0.28.1->openenv-core) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/user/miniconda/lib/python3.10/site-packages (from httpx>=0.28.1->openenv-core) (1.0.9)
# Requirement already satisfied: idna in /home/user/miniconda/lib/python3.10/site-packages (from httpx>=0.28.1->openenv-core) (3.4)
# Requirement already satisfied: h11>=0.16 in /home/user/miniconda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.28.1->openenv-core) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/user/miniconda/lib/python3.10/site-packages (from huggingface_hub>=0.25.0->peft) (1.4.3)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.6/358.6 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/miniconda/lib/python3.10/site-packages (from pydantic>=2.0.0->openenv-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /home/user/miniconda/lib/python3.10/site-packages (from pydantic>=2.0.0->openenv-core) (2.46.3)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/user/miniconda/lib/python3.10/site-packages (from requests>=2.25.0->openenv-core) (1.26.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/user/miniconda/lib/python3.10/site-packages (from requests>=2.25.0->openenv-core) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/user/miniconda/lib/python3.10/site-packages (from rich>=13.0.0->openenv-core) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/user/miniconda/lib/python3.10/site-packages (from rich>=13.0.0->openenv-core) (2.20.0)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.4.5)
# Requirement already satisfied: sympy>=1.13.3 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.3.3.83)
# Requirement already satisfied: networkx>=2.5.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.9.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (10.3.9.90)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: triton==3.6.0 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.6.0)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.13.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.4.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.5.8.93)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/user/miniconda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/user/miniconda/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft) (1.5.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/user/miniconda/lib/python3.10/site-packages (from transformers>=4.55.0->trl==0.22.0) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/user/miniconda/lib/python3.10/site-packages (from transformers>=4.55.0->trl==0.22.0) (0.22.2)
# Requirement already satisfied: click>=8.2.1 in /home/user/miniconda/lib/python3.10/site-packages (from typer>=0.9.0->openenv-core) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from typer>=0.9.0->openenv-core) (1.5.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/user/miniconda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Collecting joserfc>=1.6.0
#   Downloading joserfc-1.6.4-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: cryptography in /home/user/miniconda/lib/python3.10/site-packages (from authlib>=1.6.5->fastmcp>=3.0.0->openenv-core) (38.0.1)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /home/user/miniconda/lib/python3.10/site-packages (from cyclopts>=4.0.0->fastmcp>=3.0.0->openenv-core) (0.18.0)
# Collecting rich-rst<2.0.0,>=1.3.1
#   Downloading rich_rst-1.3.2-py3-none-any.whl (12 kB)
# Collecting pathable<0.6.0,>=0.5.0
# ...
# Step 6: ask_for_clarification -> Reward: -0.37 | Total: +0.09
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: -0.67 | Total: -0.58
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: -0.67 | Total: -1.25
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: -1.62
# Collecting rollouts:  90%|█████████ | 27/30 [08:06<00:52, 17.48s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: -0.79
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: auto_reply -> Reward: +0.93 | Total: +0.56
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: ask_for_clarification -> Reward: -0.37 | Total: +0.19
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: auto_reply -> Reward: +1.14 | Total: +1.33
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: +2.16
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: -0.98 | Total: +1.18
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: route_to_human -> Reward: +0.83 | Total: +2.01
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: -0.67 | Total: +1.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: route_to_human -> Reward: -0.97 | Total: +0.37
# Collecting rollouts:  93%|█████████▎| 28/30 [08:24<00:35, 17.53s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: route_to_human -> Reward: +0.83 | Total: +1.20
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: ask_for_clarification -> Reward: -0.37 | Total: -0.37
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: -0.97 | Total: -1.34
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: auto_reply -> Reward: -0.67 | Total: -2.01
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: auto_reply -> Reward: +0.93 | Total: -1.08
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: -0.25
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: route_to_human -> Reward: +0.83 | Total: +0.58
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: -0.67 | Total: -0.09
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: route_to_human -> Reward: +0.83 | Total: +0.74
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: auto_reply -> Reward: +0.93 | Total: +1.67
# Collecting rollouts:  97%|█████████▋| 29/30 [08:44<00:18, 18.50s/it]Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 10: ask_for_clarification -> Reward: -0.37 | Total: +1.30
# ✅ Successfully loaded 100 emails from dataset.json
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 1: auto_reply -> Reward: -0.67 | Total: -0.67
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 2: route_to_human -> Reward: -0.98 | Total: -1.65
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 3: route_to_human -> Reward: -0.97 | Total: -2.62
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 4: ask_for_clarification -> Reward: -0.37 | Total: -2.99
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 5: route_to_human -> Reward: +0.83 | Total: -2.16
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 6: auto_reply -> Reward: +0.94 | Total: -1.22
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 7: auto_reply -> Reward: +1.14 | Total: -0.08
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 8: auto_reply -> Reward: +0.93 | Total: +0.85
# Both `max_new_tokens` (=300) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Step 9: ask_for_clarification -> Reward: -0.37 | Total: +0.48
# Collecting rollouts: 100%|██████████| 30/30 [09:07<00:00, 18.25s/it]
# Step 10: auto_reply -> Reward: -0.67 | Total: -0.19
# Collected 300 transitions
# Filtering for successful behaviors...
# Found 155 highly successful actions to train on!
# Configuring SFT Trainer...
# Unsloth: Tokenizing ["text"] (num_proc=12):   0%|          | 0/155 [00:00<?, ? examples/s]
# Starting Behavioral Cloning Training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 155 | Num Epochs = 6 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 4 x 1) = 16
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 01:55, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.218561</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.084760</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.896142</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.639816</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.465656</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.320642</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.124683</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.934152</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.790441</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.611884</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.502236</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.408430</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.369892</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.311464</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.300279</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.287378</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.276146</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.269399</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.251536</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.247615</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.240779</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.221691</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.237932</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.228482</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.203035</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.213025</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.213263</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.185184</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.189727</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.181387</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.182723</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.181346</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.177749</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.170364</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.185073</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.161373</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.176234</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.171700</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.156271</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.155098</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.151030</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.148465</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.151539</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.154869</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.157305</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.145068</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.155781</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.147167</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.141449</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.151199</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.138040</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.135619</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.142855</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.129193</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.134665</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.140413</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.133613</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.132716</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.149754</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.159315</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in email-triage-lora-final/checkpoint-60/tokenizer_config.json.
# Training completed! Saving LoRA adapters...
# Unsloth: Restored added_tokens_decoder metadata in email-triage-lora-final/tokenizer_config.json.
# SUCCESS: Model weights saved locally!
# Generating validation plots...
# ✅ Saved training_loss.png
# ✅ Saved reward_curve.png
# 🎉 ALL TASKS COMPLETE. Script is ready for judging!

# %%
from huggingface_hub import HfApi
import os

# Grab your token
hf_token = os.environ.get("HF_TOKEN") 

api = HfApi(token=hf_token)

print("Uploading to Hugging Face Hub... this might take a minute...")

api.upload_file(
    path_or_fileobj="/home/user/app/email-triage-lora-final.tar.gz",
    path_in_repo="email-triage-lora-final.tar.gz",
    repo_id="Proteinrequired/email-agent-training",
    repo_type="space"
)

print("✅ Upload complete! Check your Space's Files tab.")
# Out:
# Uploading to Hugging Face Hub... this might take a minute...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✅ Upload complete! Check your Space's Files tab.
